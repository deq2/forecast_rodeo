# %% [markdown]
# # Batch 2011-2018 backward stepwise
#
# Generate MultiLLR (local linear regression with multitask model selection) forecasts for all dates, 2011-2018, using the batch cluster or, optionally, local sequential execution.

# %%
# Autoreload packages that are modified
# %load_ext autoreload
# %autoreload 2

# Load relevant packages
import numpy as np
import pandas as pd
from sklearn import *
import sys
import subprocess
from datetime import datetime, timedelta
import netCDF4
import time
from functools import partial
import os

if os.path.basename(os.getcwd()) == "experiments":
    os.chdir(os.path.join("..",".."))

# Adds 'experiments' folder to path to load experiments_util
sys.path.insert(0, 'src/experiments')
# Load general utility functions
from experiments_util import *
# Load functionality for fitting and predicting
from fit_and_predict import *
# Load functionality for evaluation
from skill import *
# Load functionality for stepwise regression
from stepwise_util import *

# %%
#
# Choose experiment parameters
#
tic()
gt_id = "contest_tmp2m" # "contest_precip" or "contest_tmp2m"
target_horizon = "34w" # "34w" or "56w"
margin_in_days = 56
criterion = "mean"

# If run_locally is False, forecast generation jobs for each target date 
# are submitted to a batch cluster using batch_script (recommended)
# If run_locally is True, forecast generation for each target data is 
# executed locally and sequentially and the setting of batch_script is irrelevant
run_locally = False
# Shell script for submitting batch job to cluster; please change to your personal 
# batch cluster submission script.
# Usage for our script is:
#   src/batch/quick_sbatch_python script.py\ script_arg1\ script_arg2 num_cores mem
batch_script = 'src/batch/quick_sbatch_python.sh'
num_cores = 2
mem = "8GB"

contest_id = get_contest_id(gt_id, target_horizon)

#
# Create list of submission dates in YYYYMMDD format
#
submission_dates = [datetime(y,4,18)+timedelta(14*i) for y in range(2011,2018) for i in range(26)]
submission_dates = ['{}{:02d}{:02d}'.format(date.year, date.month, date.day) for date in submission_dates]
toc()
# Out:
# Elapsed time: 0.000902 seconds.

# %%
len(submission_dates)
# Out:
# 182

# %%
#
# Generate forecasts for each date by submitting batch job or executing locally
#
cmds = []
fitting_script = '/datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py'
for submission_date_str in submission_dates:
    t = time.time()
    # Load result file name for checking convergence for this submission date
    file_name = default_result_file_names(
        gt_id = gt_id, 
        target_horizon = target_horizon, 
        margin_in_days = margin_in_days,
        criterion = criterion,
        submission_date_str = submission_date_str,
        procedure = "backward_stepwise",
        hindcast_folder = False,
        hindcast_features = False,
        use_knn1 = False)["converged"]
    file_name = file_name.replace("contest_period", "2011-2018")
    # Only run job if result file does not yet exist
    if not os.path.exists(file_name):        
        if run_locally:
            # Execute command locally
            cmd = "{} {} {} {} {} {} {} {} {}".format(
                "python", fitting_script, 
                gt_id, target_horizon,  
                margin_in_days, criterion,
                False, submission_date_str, num_cores)
        else:
            # Submit batch job
            cmd = r"""{} {} {} {} {} {} {} {} {} {} {}""".format(
                "python", fitting_script,
                gt_id, target_horizon, 
                margin_in_days, criterion,
                False,
                submission_date_str, num_cores,
                num_cores, mem)
        print cmd
        cmds.append(cmd)
#         os.system(cmd)
        print 'Elapsed time ' + str(time.time() - t)
# Out:
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20110808 2 2 8GB
# Elapsed time 0.000109910964966
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20110822 2 2 8GB
# Elapsed time 0.000545024871826
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20110905 2 2 8GB
# Elapsed time 0.000243902206421
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20110919 2 2 8GB
# Elapsed time 0.000288963317871
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20111003 2 2 8GB
# Elapsed time 0.00019097328186
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20111017 2 2 8GB
# Elapsed time 0.000313997268677
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20111031 2 2 8GB
# Elapsed time 0.000344038009644
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20111114 2 2 8GB
# Elapsed time 0.000410079956055
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20111128 2 2 8GB
# Elapsed time 0.000176906585693
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20111212 2 2 8GB
# Elapsed time 0.000251054763794
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20111226 2 2 8GB
# Elapsed time 9.08374786377e-05
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120109 2 2 8GB
# Elapsed time 6.103515625e-05
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120123 2 2 8GB
# Elapsed time 6.19888305664e-05
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120206 2 2 8GB
# Elapsed time 4.79221343994e-05
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120220 2 2 8GB
# Elapsed time 0.00224208831787
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120305 2 2 8GB
# Elapsed time 0.000162124633789
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120319 2 2 8GB
# Elapsed time 0.000401973724365
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120402 2 2 8GB
# Elapsed time 0.000140905380249
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120418 2 2 8GB
# Elapsed time 7.89165496826e-05
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120502 2 2 8GB
# Elapsed time 0.000102996826172
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120516 2 2 8GB
# Elapsed time 7.20024108887e-05
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120530 2 2 8GB
# Elapsed time 0.00021505355835
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120613 2 2 8GB
# Elapsed time 9.98973846436e-05
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120627 2 2 8GB
# Elapsed time 0.0001220703125
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120711 2 2 8GB
# Elapsed time 0.000182867050171
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120725 2 2 8GB
# Elapsed time 0.000115156173706
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120808 2 2 8GB
# Elapsed time 0.000220060348511
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120822 2 2 8GB
# Elapsed time 0.000241994857788
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120905 2 2 8GB
# Elapsed time 0.000276803970337
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120919 2 2 8GB
# Elapsed time 0.000146150588989
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20121003 2 2 8GB
# Elapsed time 0.000154972076416
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20121017 2 2 8GB
# Elapsed time 0.000193119049072
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20121031 2 2 8GB
# Elapsed time 6.79492950439e-05
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20121114 2 2 8GB
# Elapsed time 0.000160932540894
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20121128 2 2 8GB
# Elapsed time 9.70363616943e-05
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20121212 2 2 8GB
# Elapsed time 0.000218152999878
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20121226 2 2 8GB
# Elapsed time 0.000308036804199
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130109 2 2 8GB
# Elapsed time 0.000202894210815
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130123 2 2 8GB
# Elapsed time 0.000211954116821
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130206 2 2 8GB
# Elapsed time 0.000159025192261
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130220 2 2 8GB
# Elapsed time 0.000188112258911
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130306 2 2 8GB
# Elapsed time 0.000201940536499
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130320 2 2 8GB
# Elapsed time 0.000157833099365
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130403 2 2 8GB
# Elapsed time 0.000144004821777
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130418 2 2 8GB
# Elapsed time 8.9168548584e-05
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130502 2 2 8GB
# Elapsed time 0.000192880630493
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130516 2 2 8GB
# Elapsed time 0.000168085098267
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130530 2 2 8GB
# Elapsed time 9.79900360107e-05
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130613 2 2 8GB
# Elapsed time 0.000105857849121
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130627 2 2 8GB
# Elapsed time 0.000294923782349
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130711 2 2 8GB
# Elapsed time 0.000271797180176
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130725 2 2 8GB
# Elapsed time 0.000247955322266
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130808 2 2 8GB
# Elapsed time 0.000236034393311
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170905 2 2 8GB
# Elapsed time 0.000266075134277
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170919 2 2 8GB
# Elapsed time 0.00019097328186
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20171003 2 2 8GB
# Elapsed time 6.91413879395e-05
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20171017 2 2 8GB
# Elapsed time 0.000231981277466
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20171031 2 2 8GB
# Elapsed time 0.000358104705811
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20171114 2 2 8GB
# Elapsed time 0.000306129455566
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20171128 2 2 8GB
# Elapsed time 0.000359058380127
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20171212 2 2 8GB
# Elapsed time 0.000308990478516
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20171226 2 2 8GB
# Elapsed time 0.000266075134277
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20180109 2 2 8GB
# Elapsed time 0.0001380443573
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20180123 2 2 8GB
# Elapsed time 0.000248908996582
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20180206 2 2 8GB
# Elapsed time 0.000205039978027
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20180220 2 2 8GB
# Elapsed time 0.00012993812561
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20180306 2 2 8GB
# Elapsed time 7.29560852051e-05
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20180320 2 2 8GB
# Elapsed time 0.000200033187866
# python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20180403 2 2 8GB
# Elapsed time 0.000574111938477

# %%
cmds
# Out:
# ['python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20110808 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20110822 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20110905 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20110919 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20111003 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20111017 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20111031 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20111114 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20111128 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20111212 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20111226 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120109 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120123 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120206 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120220 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120305 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120319 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120402 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120418 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120502 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120516 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120530 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120613 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120627 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120711 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120725 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120808 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120822 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120905 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20120919 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20121003 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20121017 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20121031 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20121114 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20121128 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20121212 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20121226 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130109 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130123 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130206 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130220 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130306 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130320 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130403 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130418 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130502 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130516 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130530 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130613 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130627 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130711 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130725 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130808 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130822 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130905 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20130919 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20131003 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20131017 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20131031 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20131114 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20131128 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20131212 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20131226 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140109 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140123 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140206 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140220 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140306 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140320 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140403 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140418 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140502 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140516 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140530 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140613 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140627 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140711 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140725 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140808 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140822 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140905 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20140919 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20141003 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20141017 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20141031 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20141114 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20141128 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20141212 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20141226 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150109 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150123 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150206 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150220 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150306 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150320 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150403 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150418 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150502 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150516 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150530 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150613 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150627 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150711 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150725 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150808 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150822 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150905 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20150919 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20151003 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20151017 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20151031 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20151114 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20151128 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20151212 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20151226 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160109 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160123 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160206 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160220 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160305 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160319 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160402 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160418 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160502 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160516 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160530 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160613 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160627 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160711 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160725 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160808 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160822 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160905 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20160919 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20161003 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20161017 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20161031 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20161114 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20161128 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20161212 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20161226 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170109 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170123 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170206 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170220 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170306 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170320 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170403 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170418 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170502 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170516 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170530 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170613 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170627 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170711 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170725 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170808 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170822 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170905 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20170919 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20171003 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20171017 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20171031 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20171114 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20171128 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20171212 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20171226 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20180109 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20180123 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20180206 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20180220 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20180306 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20180320 2 2 8GB',
#  'python /datadrive/forecast_rodeo/src/experiments/2011-2018_backward_stepwise.py contest_tmp2m 34w 56 mean False 20180403 2 2 8GB']

# %%
import json

# %%
tasks = []
for i, cmd in enumerate(cmds):
    task = {
        "id": "task{}".format(i),
        "displayName": "displayName{}".format(i),
        "commandLine": cmd,
        "constraints": {
            "maxWallClockTime": "P1D",
            "maxTaskRetryCount": 2
        }
    }
    tasks.append(task)
    break

# %%
# j = json.dumps(tasks)
with open('task.json', 'w') as f:
    json.dump(tasks, f, indent=2)
